# %%
from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
lines = open('fra.txt', encoding='utf-8').read().split('\n')

# %%
eng_sent = []
fra_sent = []
eng_chars = set()
fra_chars = set()
nb_samples = 10000

# Process english and french sentences
for line in range(nb_samples):
    
    eng_line = str(lines[line]).split('\t')[0]
    
    # Append '\t' for start of the sentence and '\n' to signify end of the sentence
    fra_line = '\t' + str(lines[line]).split('\t')[1] + '\n'
    eng_sent.append(eng_line)
    fra_sent.append(fra_line)
    
    for ch in eng_line:
        if (ch not in eng_chars):
            eng_chars.add(ch)
            
    for ch in fra_line:
        if (ch not in fra_chars):
            fra_chars.add(ch)

# %%
fra_chars = sorted(list(fra_chars))
eng_chars = sorted(list(eng_chars))

# %%
# dictionary to index each english character - key is index and value is english character
eng_index_to_char_dict = {}

# dictionary to get english character given its index - key is english character and value is index
eng_char_to_index_dict = {}

for k, v in enumerate(eng_chars):
    eng_index_to_char_dict[k] = v
    eng_char_to_index_dict[v] = k

# %%
# dictionary to index each french character - key is index and value is french character
fra_index_to_char_dict = {}

# dictionary to get french character given its index - key is french character and value is index
fra_char_to_index_dict = {}
for k, v in enumerate(fra_chars):
    fra_index_to_char_dict[k] = v
    fra_char_to_index_dict[v] = k

# %%
max_len_eng_sent = max([len(line) for line in eng_sentences])
max_len_fra_sent = max([len(line) for line in fra_sentences])

# %%
max_len_eng_sent
max_len_fra_sent
# Out:
# 16
# 59

# %%
tokenized_eng_sentences = np.zeros(shape = (nb_samples,max_len_eng_sent,len(eng_chars)), dtype='float32')
tokenized_fra_sentences = np.zeros(shape = (nb_samples,max_len_fra_sent,len(fra_chars)), dtype='float32')
target_data = np.zeros((nb_samples, max_len_fra_sent, len(fra_chars)),dtype='float32')

# %%
# Vectorize the english and french sentences

for i in range(nb_samples):
    for k,ch in enumerate(eng_sent[i]):
        tokenized_eng_sentences[i,k,eng_char_to_index_dict[ch]] = 1
        
    for k,ch in enumerate(fra_sent[i]):
        tokenized_fra_sentences[i,k,fra_char_to_index_dict[ch]] = 1

        # decoder_target_data will be ahead by one timestep and will not include the start character.
        if k > 0:
            target_data[i,k-1,fra_char_to_index_dict[ch]] = 1

# %%
# Encoder model

encoder_input = Input(shape=(None,len(eng_chars)))
encoder_LSTM = LSTM(256,return_state = True)
encoder_outputs, encoder_h, encoder_c = encoder_LSTM (encoder_input)
encoder_states = [encoder_h, encoder_c]

# %%
# Decoder model

decoder_input = Input(shape=(None,len(fra_chars)))
decoder_LSTM = LSTM(256,return_sequences=True, return_state = True)
decoder_out, _ , _ = decoder_LSTM(decoder_input, initial_state=encoder_states)
decoder_dense = Dense(len(fra_chars),activation='softmax')
decoder_out = decoder_dense (decoder_out)

# %%
model = Model(inputs=[encoder_input, decoder_input],outputs=[decoder_out])

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.fit(x=[tokenized_eng_sentences,tokenized_fra_sentences], 
          y=target_data,
          batch_size=64,
          epochs=50,
          validation_split=0.2)
# Out:
# Train on 8000 samples, validate on 2000 samples
# Epoch 1/50
# 8000/8000 [==============================] - 162s - loss: 0.9289 - val_loss: 0.9727
# Epoch 2/50
# 8000/8000 [==============================] - 159s - loss: 0.7325 - val_loss: 0.7887
# Epoch 3/50
# 8000/8000 [==============================] - 160s - loss: 0.6220 - val_loss: 0.7142
# Epoch 4/50
# 8000/8000 [==============================] - 160s - loss: 0.5667 - val_loss: 0.6655
# Epoch 5/50
# 8000/8000 [==============================] - 159s - loss: 0.5291 - val_loss: 0.6368
# Epoch 6/50
# 8000/8000 [==============================] - 161s - loss: 0.4968 - val_loss: 0.6020
# Epoch 7/50
# 8000/8000 [==============================] - 160s - loss: 0.4705 - val_loss: 0.5842
# Epoch 8/50
# 8000/8000 [==============================] - 161s - loss: 0.4473 - val_loss: 0.5685
# Epoch 9/50
# 8000/8000 [==============================] - 161s - loss: 0.4277 - val_loss: 0.5463
# Epoch 10/50
# 8000/8000 [==============================] - 162s - loss: 0.4099 - val_loss: 0.5366
# Epoch 11/50
# 8000/8000 [==============================] - 162s - loss: 0.3944 - val_loss: 0.5280
# Epoch 12/50
# 8000/8000 [==============================] - 673s - loss: 0.3797 - val_loss: 0.5168
# Epoch 13/50
# 8000/8000 [==============================] - 145s - loss: 0.3663 - val_loss: 0.5134
# Epoch 14/50
# 8000/8000 [==============================] - 168s - loss: 0.3535 - val_loss: 0.5041
# Epoch 15/50
# 8000/8000 [==============================] - 174s - loss: 0.3414 - val_loss: 0.4955
# Epoch 16/50
# 8000/8000 [==============================] - 158s - loss: 0.3301 - val_loss: 0.4975
# Epoch 17/50
# 8000/8000 [==============================] - 158s - loss: 0.3193 - val_loss: 0.4935
# Epoch 18/50
# 8000/8000 [==============================] - 158s - loss: 0.3092 - val_loss: 0.4919
# Epoch 19/50
# 8000/8000 [==============================] - 159s - loss: 0.2995 - val_loss: 0.4961
# Epoch 20/50
# 8000/8000 [==============================] - 159s - loss: 0.2903 - val_loss: 0.4871
# Epoch 21/50
# 8000/8000 [==============================] - 159s - loss: 0.2813 - val_loss: 0.4859
# Epoch 22/50
# 8000/8000 [==============================] - 159s - loss: 0.2729 - val_loss: 0.4858
# Epoch 23/50
# 8000/8000 [==============================] - 160s - loss: 0.2647 - val_loss: 0.4853
# Epoch 24/50
# 5504/8000 [===================>..........] - ETA: 3281s - loss: 0.2559
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-172-61e44e3d6b4d> in <module>()
#       3 # Run training
#       4 model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
# ----> 5 model.fit(x=[tokenized_eng_sentences,tokenized_fra_sentences], y=target_data, batch_size=64, epochs=50, validation_split=0.2)
#
# C:\Users\kmsra_000\Anaconda3\lib\site-packages\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, **kwargs)
#    1596                               initial_epoch=initial_epoch,
#    1597                               steps_per_epoch=steps_per_epoch,
# -> 1598                               validation_steps=validation_steps)
#    1599
#    1600     def evaluate(self, x, y,
#
# C:\Users\kmsra_000\Anaconda3\lib\site-packages\keras\engine\training.py in _fit_loop(self, f, ins, out_labels, batch_size, epochs, verbose, callbacks, val_f, val_ins, shuffle, callback_metrics, initial_epoch, steps_per_epoch, validation_steps)
#    1181                     batch_logs['size'] = len(batch_ids)
#    1182                     callbacks.on_batch_begin(batch_index, batch_logs)
# -> 1183                     outs = f(ins_batch)
#    1184                     if not isinstance(outs, list):
#    1185                         outs = [outs]
#
# C:\Users\kmsra_000\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in __call__(self, inputs)
#    2271         updated = session.run(self.outputs + [self.updates_op],
#    2272                               feed_dict=feed_dict,
# -> 2273                               **self.session_kwargs)
#    2274         return updated[:len(self.outputs)]
#    2275
#
# C:\Users\kmsra_000\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in run(self, fetches, feed_dict, options, run_metadata)
#     893     try:
#     894       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 895                          run_metadata_ptr)
#     896       if run_metadata:
#     897         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# C:\Users\kmsra_000\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1122     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1123       results = self._do_run(handle, final_targets, final_fetches,
# -> 1124                              feed_dict_tensor, options, run_metadata)
#    1125     else:
#    1126       results = []
#
# C:\Users\kmsra_000\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1319     if handle is None:
#    1320       return self._do_call(_run_fn, self._session, feeds, fetches, targets,
# -> 1321                            options, run_metadata)
#    1322     else:
#    1323       return self._do_call(_prun_fn, self._session, handle, feeds, fetches)
#
# C:\Users\kmsra_000\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _do_call(self, fn, *args)
#    1325   def _do_call(self, fn, *args):
#    1326     try:
# -> 1327       return fn(*args)
#    1328     except errors.OpError as e:
#    1329       message = compat.as_text(e.message)
#
# C:\Users\kmsra_000\Anaconda3\lib\site-packages\tensorflow\python\client\session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1304           return tf_session.TF_Run(session, options,
#    1305                                    feed_dict, fetch_list, target_list,
# -> 1306                                    status, run_metadata)
#    1307
#    1308     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %%
# Inference models for testing

# Encoder inference model
encoder_model_inf = Model(encoder_input, encoder_states)

# Decoder inference model
decoder_state_input_h = Input(shape=(256,))
decoder_state_input_c = Input(shape=(256,))
decoder_input_states = [decoder_state_input_h, decoder_state_input_c]

decoder_out, decoder_h, decoder_c = decoder_LSTM(decoder_input, 
                                                 initial_state=decoder_input_states)

decoder_states = [decoder_h , decoder_c]

decoder_out = decoder_dense(decoder_out)

decoder_model_inf = Model(inputs=[decoder_input] + decoder_input_states,
                          outputs=[decoder_out] + decoder_states )

# %%
def decode_seq(inp_seq):
    
    # Initial states value is coming from the encoder 
    states_val = encoder_model_inf.predict(inp_seq)
    
    target_seq = np.zeros((1, 1, len(fra_chars)))
    target_seq[0, 0, fra_char_to_index_dict['\t']] = 1
    
    translated_sent = ''
    stop_condition = False
    
    while not stop_condition:
        
        decoder_out, decoder_h, decoder_c = decoder_model_inf.predict(x=[target_seq] + states_val)
        
        max_val_index = np.argmax(decoder_out[0,-1,:])
        sampled_fra_char = fra_index_to_char_dict[max_val_index]
        translated_sent += sampled_fra_char
        
        if ( (sampled_fra_char == '\n') or (len(translated_sent) > max_len_fra_sent)) :
            stop_condition = True
        
        target_seq = np.zeros((1, 1, len(fra_chars)))
        target_seq[0, 0, max_val_index] = 1
        
        states_val = [decoder_h, decoder_c]
        
    return translated_sent

# %%
for seq_index in range(10):
    inp_seq = tokenized_eng_sentences[seq_index:seq_index+1]
    translated_sent = decode_seq(inp_seq)
    print('-')
    print('Input sentence:', eng_sent[seq_index])
    print('Decoded sentence:', translated_sent)
# Out:
# -
# Input sentence: ﻿Go.
# Decoded sentence: Va chercher !
#
# -
# Input sentence: Run!
# Decoded sentence: Arrête de travailler !
#
# -
# Input sentence: Run!
# Decoded sentence: Arrête de travailler !
#
# -
# Input sentence: Wow!
# Decoded sentence: Attention !
#
# -
# Input sentence: Fire!
# Decoded sentence: Attendez !
#
# -
# Input sentence: Help!
# Decoded sentence: Restez avec moi.
#
# -
# Input sentence: Jump.
# Decoded sentence: Va chercher tommentante !
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête de te la percher !
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête de te la percher !
#
# -
# Input sentence: Stop!
# Decoded sentence: Arrête de te la percher !

# %%
fra_sent
# Out:
# ['\tVa !\n',
#  '\tCours\u202f!\n',
#  '\tCourez\u202f!\n',
#  '\tÇa alors\u202f!\n',
#  '\tAu feu !\n',
#  "\tÀ l'aide\u202f!\n",
#  '\tSaute.\n',
#  '\tÇa suffit\u202f!\n',
#  '\tStop\u202f!\n',
#  '\tArrête-toi !\n',
#  '\tAttends !\n',
#  '\tAttendez !\n',
#  '\tJe comprends.\n',
#  "\tJ'essaye.\n",
#  "\tJ'ai gagné !\n",
#  "\tJe l'ai emporté !\n",
#  '\tOh non !\n',
#  '\tAttaque !\n',
#  '\tAttaquez !\n',
#  '\tSanté !\n',
#  '\tÀ votre santé !\n',
#  '\tMerci !\n',
#  '\tTchin-tchin !\n',
#  '\tLève-toi.\n',
#  "\tJ'ai pigé !\n",
#  '\tCompris !\n',
#  '\tPigé\u202f?\n',
#  '\tCompris\u202f?\n',
#  "\tT'as capté\u202f?\n",
#  '\tMonte.\n',
#  '\tMontez.\n',
#  '\tSerre-moi dans tes bras !\n',
#  '\tSerrez-moi dans vos bras !\n',
#  '\tJe suis tombée.\n',
#  '\tJe suis tombé.\n',
#  '\tJe sais.\n',
#  '\tJe suis parti.\n',
#  '\tJe suis partie.\n',
#  "\tJ'ai perdu.\n",
#  "\tJ'ai 19 ans.\n",
#  '\tJe vais bien.\n',
#  '\tÇa va.\n',
#  '\tÉcoutez !\n',
#  "\tC'est pas possible\u202f!\n",
#  '\tImpossible\u202f!\n',
#  '\tEn aucun cas.\n',
#  "\tC'est hors de question !\n",
#  "\tIl n'en est pas question !\n",
#  "\tC'est exclu !\n",
#  '\tEn aucune manière !\n',
#  '\tHors de question !\n',
#  '\tVraiment\u202f?\n',
#  '\tVrai ?\n',
#  '\tAh bon ?\n',
#  '\tMerci !\n',
#  '\tOn essaye.\n',
#  '\tNous avons gagné.\n',
#  '\tNous gagnâmes.\n',
#  "\tNous l'avons emporté.\n",
#  "\tNous l'emportâmes.\n",
#  '\tDemande à Tom.\n',
#  '\tFantastique\u202f!\n',
#  '\tSois calme !\n',
#  '\tSoyez calme !\n',
#  '\tSoyez calmes !\n',
#  '\tSois détendu !\n',
#  '\tSois juste !\n',
#  '\tSoyez juste !\n',
#  '\tSoyez justes !\n',
#  '\tSois équitable !\n',
#  '\tSoyez équitable !\n',
#  '\tSoyez équitables !\n',
#  '\tSois gentil.\n',
#  '\tSois gentil !\n',
#  '\tSois gentille !\n',
#  '\tSoyez gentil !\n',
#  '\tSoyez gentille !\n',
#  '\tSoyez gentils !\n',
#  '\tSoyez gentilles !\n',
#  '\tDégage\u202f!\n',
#  '\tAppelle-moi !\n',
#  '\tAppellez-moi !\n',
#  '\tAppelle-nous !\n',
#  '\tAppelez-nous !\n',
#  '\tEntrez\u202f!\n',
#  '\tEntre.\n',
#  '\tEntre !\n',
#  '\tEntrez !\n',
#  '\tAllez\u202f!\n',
#  '\tAllez !\n',
#  '\tViens !\n',
#  '\tVenez !\n',
#  '\tLaisse tomber !\n',
#  '\tLaissez tomber !\n',
#  '\tLaisse-le tomber !\n',
#  '\tLaissez-le tomber !\n',
#  '\tSortez\u202f!\n',
#  '\tSors !\n',
#  '\tSortez !\n',
#  '\tSors.\n',
#  '\tCasse-toi.\n',
#  '\tDégage\u202f!\n',
#  '\tPars !\n',
#  '\tVa te faire foutre !\n',
#  '\tPars !\n',
#  '\tDégage !\n',
#  '\tFous le camp !\n',
#  "\tPars d'ici.\n",
#  "\tVa t'en !\n",
#  '\tDisparais !\n',
#  '\tAllez-vous en !\n',
#  '\tVa doucement !\n',
#  '\tAllez doucement !\n',
#  '\tÀ la revoyure.\n',
#  '\tAttends un peu !\n',
#  '\tAttendez un peu !\n',
#  '\tTiens bon !\n',
#  '\tTenez bon !\n',
#  '\tIl laissa tomber.\n',
#  '\tIl a laissé tomber.\n',
#  '\tIl court.\n',
#  '\tAide-moi !\n',
#  '\tAide-moi.\n',
#  '\tAidez-moi.\n',
#  '\tAidez-nous !\n',
#  '\tAide-nous !\n',
#  '\tNe bouge plus !\n',
#  '\tNe quittez pas.\n',
#  '\tJe suis du même avis.\n',
#  '\tJe conduis.\n',
#  "\tJ'essayai.\n",
#  "\tJ'ai essayé.\n",
#  "\tJ'ai tenté.\n",
#  "\tJ'irai.\n",
#  '\tJe suis gras.\n',
#  '\tJe suis gros.\n',
#  '\tJe suis en forme.\n',
#  '\tJe suis touché !\n',
#  '\tJe suis touchée !\n',
#  '\tJe suis malade.\n',
#  '\tJe suis triste.\n',
#  '\tJe suis timide.\n',
#  '\tJe suis mouillé.\n',
#  '\tJe suis mouillée.\n',
#  "\tC'est bibi\u202f!\n",
#  '\tJoignez-vous.\n',
#  '\tJoignez-vous à nous.\n',
#  '\tGarde-le !\n',
#  '\tGardez-le !\n',
#  '\tEmbrasse-moi.\n',
#  '\tEmbrassez-moi.\n',
#  '\tMoi aussi.\n',
#  '\tOuvre-moi\u202f!\n',
#  '\tOuvre.\n',
#  '\tParfait\u202f!\n',
#  '\tÀ plus.\n',
#  '\tMontre-moi !\n',
#  '\tMontrez-moi !\n',
#  '\tTaisez-vous\u202f!\n',
#  '\tFerme-la\u202f!\n',
#  '\tTais-toi !\n',
#  '\tFerme-la !\n',
#  '\tLa ferme !\n',
#  '\tÀ plus tard !\n',
#  '\tPrends-le !\n',
#  '\tPrenez-le !\n',
#  '\tDis-moi !\n',
#  '\tDites-moi !\n',
#  '\tTom a gagné.\n',
#  '\tRéveille-toi\u202f!\n',
#  '\tRéveille-toi !\n',
#  '\tRéveillez-vous !\n',
#  '\tRéveille-toi !\n',
#  '\tRéveillez-vous !\n',
#  '\tLave-toi !\n',
#  '\tLavez-vous !\n',
#  '\tNous savons.\n',
#  '\tNous perdîmes.\n',
#  '\tNous avons perdu.\n',
#  '\tNous fûmes battus.\n',
#  '\tNous fûmes battues.\n',
#  '\tNous fûmes défaits.\n',
#  '\tNous fûmes défaites.\n',
#  '\tNous avons été défaits.\n',
#  '\tNous avons été défaites.\n',
#  '\tNous avons été battus.\n',
#  '\tNous avons été battues.\n',
#  '\tQui a gagné ?\n',
#  "\tQui l'a emporté ?\n",
#  '\tTu cours.\n',
#  '\tSuis-je gros ?\n',
#  '\tSuis-je grosse ?\n',
#  '\tRecule\u2009!\n',
#  '\tReculez.\n',
#  '\tRetire-toi\u2009!\n',
#  '\tRetirez-vous.\n',
#  '\tSois un homme !\n',
#  '\tSoyez un homme !\n',
#  '\tSois calme !\n',
#  '\tSoyez calme !\n',
#  '\tSoyez calmes !\n',
#  '\tAucune idée.\n',
#  "\tJ'en sais foutre rien.\n",
#  '\tAppelle Tom.\n',
#  '\tAppelez Tom.\n',
#  '\tCourage\u202f!\n',
#  '\tDétends-toi\u202f!\n',
#  '\tMenottez-le.\n',
#  '\tAvance !\n',
#  '\tAvancez !\n',
#  '\tContinue à rouler !\n',
#  '\tContinuez à rouler !\n',
#  '\tLâche-toi !\n',
#  '\tDescends !\n',
#  '\tDescendez !\n',
#  '\tLâche-toi !\n',
#  '\tLâchez-vous !\n',
#  "\tVa voir ailleurs si j'y suis\u202f!\n",
#  '\tDégage\u202f!\n',
#  '\tVa au diable !\n',
#  '\tSois réaliste !\n',
#  '\tVas-y.\n',
#  '\tPoursuis !\n',
#  '\tPasse devant !\n',
#  '\tVas-y !\n',
#  '\tBien joué\u202f!\n',
#  '\tBon boulot\u202f!\n',
#  '\tBeau travail\u202f!\n',
#  '\tAttrape-le.\n',
#  '\tAttrapez-le.\n',
#  '\tAmuse-toi bien !\n',
#  '\tAmusez-vous bien !\n',
#  '\tIl essaye.\n',
#  '\tIl est mouillé.\n',
#  '\tSalut, les mecs !\n',
#  "\tComme c'est mignon\u202f!\n",
#  '\tQuelle profondeur\u202f?\n',
#  "\tComme c'est chouette !\n",
#  "\tComme c'est gentil !\n",
#  "\tC'est du joli !\n",
#  "\tComme c'est agréable !\n",
#  '\tFais-moi rire.\n',
#  '\tDépêche-toi.\n',
#  '\tGrouille\u202f!\n',
#  '\tPressez-vous !\n',
#  '\tFiça !\n',
#  '\tJe suis gras.\n',
#  "\tJe m'en suis bien sorti.\n",
#  "\tJe m'en suis bien sortie.\n",
#  "\tJe l'ai fait.\n",
#  "\tC'est moi qui l'ai fait.\n",
#  "\tJ'ai échoué.\n",
#  "\tJ'ai oublié.\n",
#  "\tJ'ai compris.\n",
#  "\tJ'ai compris.\n",
#  "\tJ'ai capté.\n",
#  '\tJe téléphonai.\n',
#  "\tJ'ai téléphoné.\n",
#  '\tJe refuse.\n',
#  '\tJe le refuse.\n',
#  "\tJe l'ai vu.\n",
#  '\tJe l’ai vu.\n',
#  '\tJe suis resté.\n',
#  '\tJe suis restée.\n',
#  "\tJe l'utilise.\n",
#  "\tJ'en fais usage.\n",
#  "\tJe m'en sers.\n",
#  '\tJe paierai.\n',
#  '\tJe vais essayer.\n',
#  "\tJ'essaierai.\n",
#  '\tJe suis revenu.\n',
#  '\tMe revoilà.\n',
#  '\tJe suis chauve.\n',
#  '\tJe suis occupé.\n',
#  '\tJe suis occupée.\n',
#  '\tJe suis calme.\n',
#  "\tJ'ai froid.\n",
#  '\tJe suis sourd.\n',
#  '\tJe suis sourde.\n',
#  "\tJ'en ai fini.\n",
#  '\tJe suis rapide.\n',
#  '\tTout va bien.\n',
#  '\tJe vais bien.\n',
#  '\tÇa va.\n',
#  '\tJe suis libre !\n',
#  '\tJe suis libre.\n',
#  '\tJe suis disponible.\n',
#  '\tJe suis repu\u202f!\n',
#  '\tJe suis rassasié\u202f!\n',
#  '\tJe suis content.\n',
#  '\tJe suis chez moi.\n',
#  '\tJe suis en retard.\n',
#  '\tJe suis paresseux.\n',
#  '\tJe suis fainéant.\n',
#  '\tJe suis paresseuse.\n',
#  '\tJe suis fainéante.\n',
#  '\tJe vais bien.\n',
#  '\tJe me porte bien.\n',
#  '\tJe suis en sécurité.\n',
#  '\tJe suis malade.\n',
#  "\tJ'en suis certain.\n",
#  '\tJe suis certain.\n',
#  "\tJ'en suis sûr.\n",
#  "\tJ'en suis sûre.\n",
#  '\tJe suis grande.\n',
#  '\tJe suis mince.\n',
#  '\tJe suis ordonné.\n',
#  '\tJe suis ordonnée.\n',
#  '\tJe suis laid.\n',
#  '\tJe suis laide.\n',
#  '\tJe suis faible.\n',
#  '\tJe vais bien.\n',
#  '\tJe me porte bien.\n',
#  "\tJ'ai gagné.\n",
#  "\tJe l'ai emporté.\n",
#  '\tElle marche.\n',
#  '\tÇa fonctionne.\n',
#  "\tC'est le sien.\n",
#  "\tC'est la sienne.\n",
#  "\tC'est nouveau.\n",
#  "\tC'est neuf.\n",
#  "\tC'est bizarre.\n",
#  '\tC’est triste.\n',
#  "\tDéfense d'entrer.\n",
#  "\tN'entrez pas.\n",
#  '\tLaisse tomber !\n',
#  '\tLaissez tomber !\n',
#  '\tLaissez-moi !\n',
#  '\tLaisse-nous !\n',
#  '\tLaissez-nous !\n',
#  '\tAllons-y !\n',
#  '\tAllons !\n',
#  '\tAllons-y !\n',
#  '\tAttention !\n',
#  '\tÉpouse-moi !\n',
#  '\tÉpousez-moi !\n',
#  '\tPuis-je partir ?\n',
#  '\tPuis-je y aller ?\n',
#  "\tPuis-je m'y rendre ?\n",
#  '\tElle est venue.\n',
#  '\tElle est morte.\n',
#  '\tElle court.\n',
#  '\tAssieds-toi !\n',
#  '\tAsseyez-vous !\n',
#  '\tAssieds-toi ici.\n',
#  '\tAsseyez-vous ici.\n',
#  '\tParle plus fort\u202f!\n',
#  '\tParlez plus fort\u202f!\n',
#  '\tArrête Tom.\n',
#  '\tStoppez Tom.\n',
#  '\tGénial\u202f!\n',
#  '\tExcellent\u202f!\n',
#  '\tFormidable !\n',
#  '\tIls gagnèrent.\n',
#  '\tElles gagnèrent.\n',
#  '\tIls ont gagné.\n',
#  '\tElles ont gagné.\n',
#  '\tTom est venu.\n',
#  '\tTom est mort.\n',
#  '\tTom est parti.\n',
#  '\tTom partit.\n',
#  '\tTom a perdu.\n',
#  '\tTrop tard.\n',
#  '\tFaites-moi confiance.\n',
#  '\tFais-moi confiance.\n',
#  '\tFais un effort.\n',
#  '\tEssaies-en !\n',
#  '\tEssayez-en !\n',
#  '\tEssaie ceci !\n',
#  '\tEssayez ceci !\n',
#  '\tUtilise ceci.\n',
#  '\tUtilisez ceci.\n',
#  '\tEmploie ceci !\n',
#  '\tEmployez ceci !\n',
#  '\tAvertis Tom.\n',
#  '\tPréviens Tom.\n',
#  '\tRegarde-moi !\n',
#  '\tRegardez-moi !\n',
#  '\tRegardez-nous !\n',
#  '\tRegarde-nous !\n',
#  "\tNous sommes d'accord.\n",
#  '\tNous irons.\n',
#  '\tPour quoi faire\u202f?\n',
#  '\tÀ quoi bon ?\n',
#  "\tQu'est-ce qu'on s'est marrés !\n",
#  "\tQu'est-ce qu'on s'est marrées !\n",
#  '\tQui est mort ?\n',
#  '\tQui est-il\u202f?\n',
#  '\tÉcris-moi !\n',
#  '\tÉcrivez-moi !\n',
#  '\tAprès vous.\n',
#  '\tEn joue ! Feu !\n',
#  '\tSuis-je en retard ?\n',
#  '\tRépondez-moi.\n',
#  '\tAssieds-toi !\n',
#  '\tAsseyez-vous !\n',
#  '\tLes oiseaux volent.\n',
#  '\tÀ tes souhaits\u202f!\n',
#  '\tAppelle à la maison !\n',
#  '\tCalmez-vous !\n',
#  '\tCalme-toi.\n',
#  '\tPouvons-nous partir ?\n',
#  '\tPouvons-nous nous en aller ?\n',
#  '\tPouvons-nous y aller ?\n',
#  '\tRattrape-le.\n',
#  '\tReviens !\n',
#  '\tRevenez !\n',
#  '\tViens ici.\n',
#  '\tVenez là.\n',
#  '\tViens\u202f!\n',
#  '\tVenez\u202f!\n',
#  '\tVenez ici !\n',
#  '\tViens chez nous !\n',
#  '\tVenez chez nous !\n',
#  '\tViens chez moi !\n',
#  '\tVenez chez moi !\n',
#  '\tViens bientôt !\n',
#  '\tVenez bientôt !\n',
#  '\tCalmez-vous !\n',
#  '\tAi-je gagné ?\n',
#  "\tL'ai-je emporté ?\n",
#  '\tEst-ce moi qui ai gagné ?\n',
#  '\tDes chiens aboient.\n',
#  '\tLes chiens aboient.\n',
#  '\tNe demande pas !\n',
#  '\tNe pleure pas !\n',
#  '\tNe meurs pas !\n',
#  '\tNe mourez pas !\n',
#  '\tNe mens pas.\n',
#  '\tNe courez pas.\n',
#  '\tNe cours pas.\n',
#  '\tExcuse-moi.\n',
#  '\tFantastique\u202f!\n',
#  '\tSens ça !\n',
#  '\tSentez ça !\n',
#  '\tTouche ça !\n',
#  '\tTouchez ça !\n',
#  '\tSuis-moi.\n',
#  '\tSuis-nous !\n',
#  '\tSuivez-nous !\n',
#  '\tOublie !\n',
#  '\tOublie-le !\n',
#  '\tOubliez !\n',
#  '\tOubliez-le !\n',
#  '\tLaisse tomber.\n',
#  '\tOublie.\n',
#  '\tTrouve un emploi !\n',
#  '\tTrouve un boulot !\n',
#  '\tTrouvez un emploi !\n',
#  '\tTrouvez un boulot !\n',
#  '\tPrépare-toi.\n',
#  '\tPréparez-vous.\n',
#  '\tVa le chercher !\n',
#  '\tAllez le chercher !\n',
#  '\tEntrez\u202f!\n',
#  '\tVa au lit !\n',
#  '\tAllez au lit !\n',
#  '\tBonne chance\u202f!\n',
#  '\tBonne chance.\n',
#  '\tAttrape ça !\n',
#  '\tAttrapez ça !\n',
#  '\tSaisis-toi de ça !\n',
#  '\tSaisissez-vous de ça !\n',
#  '\tAttrape ça !\n',
#  '\tAttrapez ça !\n',
#  '\tPas touche\u202f!\n',
#  '\tIl est malade.\n',
#  '\tIl est vieux.\n',
#  '\tIl est bon.\n',
#  '\tIl est paresseux.\n',
#  '\tIl est riche.\n',
#  '\tMe voici.\n',
#  '\tVoilà cinq dollars.\n',
#  '\tHalte au feu !\n',
#  '\tCessez le feu !\n',
#  '\tTiens ça !\n',
#  '\tTenez ça !\n',
#  '\tTenez ceci !\n',
#  '\tTiens ceci !\n',
#  "\tC'est affreux\u202f!\n",
#  '\tComment Tom va-t-il ?\n',
#  '\tComment va Tom ?\n',
#  '\tJe suis occupé.\n',
#  '\tJe suis calme.\n',
#  "\tJ'ai froid.\n",
#  '\tJe vais bien.\n',
#  '\tJe suis bon.\n',
#  '\tJe suis ici.\n',
#  '\tJe suis paresseux.\n',
#  '\tJe suis fainéant.\n',
#  '\tJe suis paresseuse.\n',
#  '\tJe suis fainéante.\n',
#  '\tJe vais bien.\n',
#  '\tJe suis malade.\n',
#  '\tJe suis sûr.\n',
#  '\tJe suis certain.\n',
#  '\tJe suis faible.\n',
#  '\tJe vous en prie.\n',
#  '\tJe vous en conjure.\n',
#  '\tJe vous en supplie.\n',
#  '\tJe te prie.\n',
#  '\tJe sais courir.\n',
#  '\tJe sais skier.\n',
#  "\tJ'eus un mouvement de recul.\n",
#  "\tJ'ai eu un mouvement de recul.\n",
#  '\tJe suis rentré en moi-même.\n',
#  "\tJ'abandonne.\n",
#  '\tJe me suis mis à avoir chaud.\n',
#  '\tJe me suis mise à avoir chaud.\n',
#  '\tJe me suis amusé.\n',
#  '\tJe me suis amusée.\n',
#  '\tJe me suis marré.\n',
#  '\tJe me suis marrée.\n',
#  '\tJe déteste ça.\n',
#  "\tJ'espère bien.\n",
#  '\tJe le savais.\n',
#  "\tJ'aime ça.\n",
#  '\tJe l’ai perdu.\n',
#  "\tJ'adore ça !\n",
#  "\tJ'adore ça !\n",
#  '\tJe suis sérieux\u202f!\n',
#  '\tJe suis sérieux.\n',
#  '\tJe dois y aller.\n',
#  "\tIl faut que j'y aille.\n",
#  '\tIl me faut y aller.\n',
#  '\tIl me faut partir.\n',
#  "\tIl me faut m'en aller.\n",
#  '\tJe dois partir.\n',
#  "\tJe dois m'en aller.\n",
#  "\tIl faut que je m'en aille.\n",
#  "\tJ'en ai besoin.\n",
#  '\tIl me le faut.\n',
#  "\tJ'ai remarqué.\n",
#  '\tJe le promets.\n',
#  '\tJe me suis détendu.\n',
#  '\tJe me suis détendue.\n',
#  "\tJ'ai dit non.\n",
#  "\tJe l'ai dit.\n",
#  "\tJe l'ai vu.\n",
#  '\tJe l’ai vu.\n',
#  '\tJe le vis.\n',
#  "\tJ'en ai vu une.\n",
#  "\tJ'en ai vu un.\n",
#  '\tJe vous vis.\n',
#  '\tJe te vis.\n',
#  "\tJe t'ai vue.\n",
#  "\tJe t'ai vu.\n",
#  '\tJe vous ai vues.\n',
#  '\tJe vous ai vus.\n',
#  '\tJe vous ai vue.\n',
#  '\tJe vous ai vu.\n',
#  '\tJe vois Tom.\n',
#  "\tJ'ai crié.\n",
#  "\tJ'ai trébuché.\n",
#  "\tJ'ai plané.\n",
#  '\tJe le veux.\n',
#  "\tJ'étais nouveau.\n",
#  "\tJ'étais nouvelle.\n",
#  "\tJ'irai.\n",
#  '\tJe me suis réveillé.\n',
#  '\tJe me suis éveillé.\n',
#  "\tJe serais d'accord.\n",
#  '\tJe partirais.\n',
#  "\tJ'appellerai.\n",
#  '\tJe cuisinerai.\n',
#  "\tJ'aiderai.\n",
#  '\tJe vivrai.\n',
#  "\tJ'obéirai.\n",
#  '\tJe ferai mon sac.\n',
#  '\tJe ferai ma valise.\n',
#  '\tJe plierai mes gaules.\n',
#  '\tJe passerai.\n',
#  "\tJ'abandonnerai.\n",
#  '\tJe chanterai.\n',
#  "\tJ'arrêterai.\n",
#  '\tJe nagerai.\n',
#  "\tJ'attendrai.\n",
#  '\tJe marcherai.\n',
#  '\tJe vais travailler.\n',
#  '\tJe travaillerai.\n',
#  '\tJe suis flic.\n',
#  '\tJe suis un homme.\n',
#  '\tJe suis en vie.\n',
#  '\tJe suis vivant.\n',
#  '\tJe suis vivante.\n',
#  '\tJe suis seule.\n',
#  '\tJe suis seul.\n',
#  '\tJe suis armé.\n',
#  '\tJe suis armée.\n',
#  '\tJe suis réveillé.\n',
#  '\tJe suis aveugle.\n',
#  '\tJe suis fauché.\n',
#  '\tJe suis fou.\n',
#  '\tJe suis folle.\n',
#  '\tJe suis guéri.\n',
#  '\tJe suis guérie.\n',
#  '\tJe suis saoul.\n',
#  '\tJe suis soûl.\n',
#  '\tJe suis ivre.\n',
#  '\tJe me meurs.\n',
#  '\tJe suis en avance.\n',
#  '\tJe suis en premier.\n',
#  '\tJe suis difficile.\n',
#  '\tJe suis tatillon.\n',
#  '\tJe suis tatillonne.\n',
#  '\tJe pars maintenant.\n',
#  '\tJe me tire.\n',
#  '\tJ’y vais.\n',
#  '\tJe pars.\n',
#  '\tJe suis loyal.\n',
#  '\tJe suis loyale.\n',
#  '\tJe suis veinard.\n',
#  '\tJe suis veinarde.\n',
#  "\tJ'ai du pot.\n",
#  '\tJe suis chanceux.\n',
#  '\tJe suis chanceuse.\n',
#  '\tJe suis en train de mentir.\n',
#  '\tJe suis tranquille.\n',
#  '\tJe suis prête !\n',
#  '\tJe suis prêt !\n',
#  '\tJe suis prêt.\n',
#  "\tJ'ai raison.\n",
#  '\tJe suis sobre.\n',
#  '\tExcuse-moi.\n',
#  '\tDésolé.\n',
#  '\tDésolé !\n',
#  '\tJe suis désolé.\n',
#  '\tJe suis désolée.\n',
#  '\tJe suis coincée.\n',
#  '\tJe suis timide.\n',
#  '\tJe suis fatigué !\n',
#  '\tJe suis dur.\n',
#  '\tJe suis dure.\n',
#  '\tJe suis dur à cuire.\n',
#  '\tJe suis dure à cuire.\n',
#  '\tJe suis à toi.\n',
#  '\tJe suis à vous.\n',
#  "\tJ'ai perdu.\n",
#  '\tEst-ce que Tom va bien ?\n',
#  '\tTom va-t-il bien ?\n',
#  "\tC'est grave\u202f?\n",
#  '\tEst-ce éloigné ?\n',
#  '\tEst-ce loin ?\n',
#  '\tEst-ce toi ?\n',
#  '\tEst-ce vous ?\n',
#  "\tEst-ce que c'est vous ?\n",
#  '\tÇa a échoué.\n',
#  "\tC'est nouveau.\n",
#  "\tC'est neuf.\n",
#  '\tIl a neigé.\n',
#  '\tÇa sent mauvais.\n',
#  '\tÇa pue.\n',
#  '\tÇa a fonctionné.\n',
#  '\tÇa a marché.\n',
#  '\tIl est trois heures et demie.\n',
#  '\tIl fait froid.\n',
#  "\tC'est froid.\n",
#  "\tC'est sombre.\n",
#  '\tElle est morte.\n',
#  "\tC'est mort.\n",
#  '\tIl est mort.\n',
#  "\tC'est fait.\n",
#  "\tC'est de la nourriture.\n",
#  "\tC'est gratuit.\n",
#  "\tC'est le sien.\n",
#  "\tC'est la sienne.\n",
#  '\tIl est tard.\n',
#  "\tC'est perdu.\n",
#  "\tC'est ouvert.\n",
#  "\tC'est le nôtre.\n",
#  "\tC'est la nôtre.\n",
#  "\tC'est à nous.\n",
#  "\tC'est du sable.\n",
#  "\tC'est vrai\u202f!\n",
#  "\tC'est du boulot.\n",
#  '\tAinsi soit-il.\n',
#  '\tLaisse faire.\n',
#  '\tLaisse-moi partir\u202f!\n',
#  '\tLaissez-moi partir\u202f!\n',
#  '\tLâche-moi\u202f!\n',
#  "\tLaisse-moi m'en aller !\n",
#  "\tLaissez-moi m'en aller !\n",
#  '\tLaissez-moi y aller !\n',
#  '\tLaisse-moi y aller !\n',
#  '\tLaisse-moi partir\u202f!\n',
#  '\tLaissez-moi partir\u202f!\n',
#  "\tLaisse-moi m'en aller !\n",
#  "\tLaissez-moi m'en aller !\n",
#  '\tLaissez-moi rentrer.\n',
#  '\tLaissez-moi entrer.\n',
#  '\tDemandons.\n',
#  '\tVoyons voir !\n',
#  '\tReste allongé, immobile !\n',
#  '\tReste allongée, immobile !\n',
#  '\tRestez allongé, immobile !\n',
#  '\tRestez allongée, immobile !\n',
#  '\tRestez allongés, immobiles !\n',
#  '\tRestez allongées, immobiles !\n',
#  '\tÉchauffe-toi !\n',
#  '\tÉchauffez-vous !\n',
#  '\tDétends-toi !\n',
#  '\tLaisse-toi aller !\n',
#  '\tLaissez-vous aller !\n',
#  '\tJoli coup !\n',
#  '\tPour sûr.\n',
#  '\tMais ouais !\n',
#  '\tBien sûr.\n',
#  '\tPour sûr.\n',
#  '\tJe vous en prie !\n',
#  "\tJe t'en prie !\n",
#  '\tPardon\u202f?\n',
#  '\tJe vous demande pardon\u202f?\n',
#  '\tPlaît-il\u202f?\n',
#  '\tLis ceci.\n',
#  '\tDis bonjour.\n',
#  '\tVoyez ci-dessus.\n',
#  '\tVraiment\u202f?\n',
#  '\tEst-ce sérieux\u202f?\n',
#  '\tSérieusement ?\n',
#  '\tElle pleurait.\n',
#  '\tElle pleura.\n',
#  '\tElle a essayé.\n',
#  '\tElle marche.\n',
#  '\tElle est chaude.\n',
#  '\tElle est très attirante.\n',
#  '\tSigne ici.\n',
#  '\tSignez ici.\n',
#  '\tRalentis !\n',
#  '\tRalentissez !\n',
#  '\tReste en arrière !\n',
#  '\tRestez en arrière !\n',
#  '\tRestez calme.\n',
#  '\tReste calme.\n',
#  '\tGarde ton calme.\n',
#  '\tGarde ton sang-froid.\n',
#  '\tReste tranquille.\n',
#  '\tReste baissé.\n',
#  '\tRestez baissé.\n',
#  '\tReste mince !\n',
#  '\tArrêtez !\n',
#  '\tArrêtez ça !\n',
#  '\tArrête ça !\n',
#  '\tPrends soin de toi.\n',
#  '\tPrenez soin de vous.\n',
#  '\tPrends le mien.\n',
#  '\tPrends la mienne.\n',
#  '\tPrenez le mien.\n',
#  '\tPrenez la mienne.\n',
#  '\tPrends les miens.\n',
#  '\tPrends les miennes.\n',
#  '\tPrenez les miens.\n',
#  '\tPrenez les miennes.\n',
#  '\tPrends ça.\n',
#  '\tPrenez ça.\n',
#  '\tMerci !\n',
#  "\tC'est ça.\n",
#  '\tIls sont tombés.\n',
#  '\tElles sont tombées.\n',
#  '\tIls sont partis.\n',
#  '\tElles sont parties.\n',
#  '\tIls ont menti.\n',
#  '\tElles ont menti.\n',
#  '\tIls ont perdu.\n',
#  '\tElles ont perdu.\n',
#  '\tIls nageaient.\n',
#  '\tElles nageaient.\n',
#  '\tIls nagèrent.\n',
#  '\tElles nagèrent.\n',
#  '\tTom tricote.\n',
#  '\tTom sait.\n',
#  '\tTom a parlé.\n',
#  '\tTom est gros.\n',
#  '\tEssaie encore.\n',
#  '\tEssayez de nouveau.\n',
#  '\tEssaie de nouveau.\n',
#  '\tEssaie-le\u2009!\n',
#  '\tTourne à gauche.\n',
#  '\tAttends ici.\n',
#  '\tAttends là.\n',
#  '\tAttendez ici.\n',
#  '\tAttendez là.\n',
#  '\tAttention !\n',
#  '\tFaites attention\u202f!\n',
#  '\tFais attention\u202f!\n',
#  "\tNous sommes tombés d'accord.\n",
#  '\tNous avons réussi\u202f!\n',
#  '\tNous avons réussi\u202f!\n',
#  "\tNous l'avons fait.\n",
#  '\tNous avons oublié.\n',
#  "\tNous l'avons vu.\n",
#  "\tNous l'avons vue.\n",
#  '\tNous discutâmes.\n',
#  '\tNous avons discuté.\n',
#  '\tNous nous sommes entretenus.\n',
#  '\tNous nous sommes entretenues.\n',
#  '\tNous nous entretînmes.\n',
#  '\tNous attendîmes.\n',
#  '\tNous avons attendu.\n',
#  '\tNous essayerons.\n',
#  '\tNous tenterons.\n',
#  "\tNous l'emporterons.\n",
#  '\tNous gagnerons.\n',
#  '\tNous avons chaud.\n',
#  '\tNous sommes tristes.\n',
#  '\tNous sommes timides.\n',
#  '\tBien vu\u202f!\n',
#  '\tBien cuit\u202f!\n',
#  '\tÀ la bonne heure\u202f!\n',
#  '\tBien joué\u202f!\n',
#  '\tPas mal !\n',
#  '\tQuoi d’autre\u202f?\n',
#  "\tQuoi d'autre ?\n",
#  '\tÇa va ?\n',
#  '\tQuoi de beau\u202f?\n',
#  "\tQui s'en préoccupe\u202f?\n",
#  "\tQui s'en soucie\u202f?\n",
#  '\tÀ qui ceci importe-t-il\u202f?\n',
#  '\tQui est-ce\u202f?\n',
#  '\tQui est-il\u202f?\n',
#  '\tQui est-ce\u202f?\n',
#  '\tQui est-il\u202f?\n',
#  '\tQui sait\u202f?\n',
#  '\tQui a parlé ?\n',
#  '\tQui ira ?\n',
#  '\tQui est malade ?\n',
#  '\tMagnifique\u202f!\n',
#  '\tÉcrivez à Tom.\n',
#  '\tTu conduis.\n',
#  '\tToi, conduis !\n',
#  '\tVous conduisez.\n',
#  "\tEspèce d'imbécile\u202f!\n",
#  "\tEspèce d'idiot\u202f!\n",
#  '\tTu commences.\n',
#  '\tVous commencez.\n',
#  '\tTu as essayé.\n',
#  '\tVous avez essayé.\n',
#  '\tTout le monde à bord!\n',
#  '\tSuis-je clair ?\n',
#  '\tSuis-je claire ?\n',
#  '\tSuis-je en train de mourir ?\n',
#  '\tSuis-je en train de trépasser ?\n',
#  '\tSuis-je en avance ?\n',
#  '\tVous me mettez à la porte ?\n',
#  '\tSuis-je le premier ?\n',
#  '\tSuis-je la première ?\n',
#  '\tSuis-je engagé ?\n',
#  '\tSuis-je engagée ?\n',
#  '\tAi-je raison ?\n',
#  '\tSuis-je dans le vrai ?\n',
#  '\tMe trompé-je\u202f?\n',
#  '\tAi-je tort ?\n',
#  '\tEst-ce que je me trompe ?\n',
#  '\tEst-ce que tu vas bien\u202f?\n',
#  '\tEs-tu levé ?\n',
#  '\tEs-tu levée ?\n',
#  '\tÊtes-vous levé ?\n',
#  '\tÊtes-vous levée ?\n',
#  '\tÊtes-vous levés ?\n',
#  '\tÊtes-vous levées ?\n',
#  '\tEs-tu debout ?\n',
#  '\tÊtes-vous debout ?\n',
#  "\tDemandez à n'importe qui.\n",
#  "\tDemande à n'importe qui.\n",
#  '\tDemande à quiconque !\n',
#  '\tDemande alentour !\n',
#  '\tDemandez alentour !\n',
#  '\tSois prudent !\n',
#  '\tSois prudente !\n',
#  '\tSoyez prudent !\n',
#  '\tSoyez prudente !\n',
#  '\tSoyez prudents !\n',
#  '\tSoyez prudentes !\n',
#  '\tSois satisfait !\n',
#  '\tSois satisfaite !\n',
#  '\tSoyez satisfait !\n',
#  '\tSoyez satisfaite !\n',
#  '\tSoyez satisfaits !\n',
#  '\tSoyez satisfaites !\n',
#  '\tSoyez sérieux !\n',
#  '\tSoyez sérieuse !\n',
#  '\tSoyez sérieuses !\n',
#  '\tSois sérieux !\n',
#  '\tSois sérieuse !\n',
#  '\tLes oiseaux chantent.\n',
#  '\tSanté !\n',
#  '\tPuis-je venir ?\n',
#  '\tPuis-je aider\u202f?\n',
#  '\tPuis-je rester ?\n',
#  '\tPorte-le.\n',
#  '\tVérifie ça.\n',
#  '\tRegarde ça.\n',
#  '\tChoisis-en un.\n',
#  '\tChoisis-en une.\n',
#  '\tJoignez-vous à nous.\n',
#  '\tEntre donc\u202f!\n',
#  '\tEntre.\n',
#  '\tViens vite\u202f!\n',
#  '\tJouis vite\u202f!\n',
#  '\tVenez à moi.\n',
#  '\tVenez à nous.\n',
#  '\tArrête !\n',
#  '\tArrêtez !\n',
#  '\tAssez\u202f!\n',
#  '\tAvons-nous gagné ?\n',
#  '\tEst-ce que je pue ?\n',
#  '\tJe vous en prie, entrez\u202f!\n',
#  '\tLes hommes pleurent-ils ?\n',
#  '\tTe tracasse pas.\n',
#  '\tVous tracassez pas.\n',
#  '\tNe te tracasse pas.\n',
#  '\tNe vous tracassez pas.\n',
#  '\tNe bouge pas !\n',
#  '\tNe bougez pas !\n',
#  '\tNe bougez pas.\n',
#  '\tNe bouge pas.\n',
#  '\tNe te précipite pas.\n',
#  '\tNe vous précipitez pas.\n',
#  '\tNe parle pas !\n',
#  '\tNe parlez pas !\n',
#  "\tN'attends pas !\n",
#  "\tN'attendez pas !\n",
#  "\tLe devoir m'appelle.\n",
#  '\tLe plein.\n',
#  '\tTrouve un emploi !\n',
#  '\tTrouve un boulot !\n',
#  '\tSuis-le\u202f!\n',
#  '\tSuivez-le\u202f!\n',
#  '\tOublie-le.\n',
#  '\tOubliez-le.\n',
#  '\tPardonnez-moi.\n',
#  '\tAchète-toi une vie !\n',
#  '\tVa au lit !\n',
#  '\tAu lit !\n',
#  '\tAllez au lit !\n',
#  '\tLaisse tomber.\n',
#  '\tAbandonne\u202f!\n',
#  "\tVa t'échauffer !\n",
#  '\tAllez vous échauffer !\n',
#  '\tIl a cédé.\n',
#  '\tIl céda.\n',
#  '\tIl a raccroché.\n',
#  '\tIl raccrocha.\n',
#  '\tIl a à faire.\n',
#  '\tIl est ici\u202f!\n',
#  '\tIl est gentil.\n',
#  '\tIl est en retard.\n',
#  '\tIl est fainéant.\n',
#  '\tIl est paresseux.\n',
#  '\tIl est pauvre.\n',
#  '\tIl est malade.\n',
#  '\tIl a réussi.\n',
#  '\tIl est Suisse.\n',
#  '\tIl est Helvète.\n',
#  '\tIl est ruiné.\n',
#  '\tIl est fauché.\n',
#  '\tIl est ivre.\n',
#  '\tIl est soûl.\n',
#  '\tIl est intelligent.\n',
#  '\tIl est ici\u202f!\n',
#  '\tLe voilà.\n',
#  '\tTenez.\n',
#  '\tLe voici.\n',
#  "\tC'est parti !\n",
#  '\tOn est partis !\n',
#  '\tTiens-toi tranquille !\n',
#  '\tTenez-vous tranquille !\n',
#  "\tComme c'est charmant !\n",
#  '\tComment va le travail ?\n',
#  "\tDépêche-toi d'aller chez toi !\n",
#  "\tDépêchez-vous d'aller chez vous !\n",
#  '\tJe suis un homme.\n',
#  '\tJe suis humain.\n',
#  '\tJe suis prêt.\n',
#  "\tJ'ai raison.\n",
#  '\tJe suis désolé.\n',
#  '\tJe suis désolée.\n',
#  '\tJe suis fatigué !\n',
#  '\tJe suis crevé.\n',
#  "\tJe l'ai cassé.\n",
#  "\tJe l'ai cassée.\n",
#  "\tJe l'ai construit.\n",
#  "\tJe l'ai construite.\n",
#  '\tJe peux venir.\n',
#  '\tJe sais cuisiner.\n',
#  '\tJe peux sauter.\n',
#  '\tJe sais lire.\n',
#  '\tJe peux lire.\n',
#  '\tJe sais chanter.\n',
#  '\tJe peux rester.\n',
#  '\tJe sais nager.\n',
#  '\tJe peux attendre.\n',
#  '\tJe peux marcher.\n',
#  '\tJe ne peux pas y aller.\n',
#  "\tJe ne peux pas m'y rendre.\n",
#  '\tJe ne peux pas partir.\n',
#  "\tJ'ai fait cela.\n",
#  "\tC'est moi qui l'ai fait.\n",
#  "\tJe ne suis pas d'accord.\n",
#  '\tJe me fais vraiment du souci.\n',
#  "\tJ'en doute.\n",
#  ...]
